# %%
import pandas as pd
import numpy as np

# %%
data_rewards=pd.read_csv("history_data_miners_rewards.csv")

# %%
data_rewards
# Out:
#       Unnamed: 0   Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0  2020-07-06        912.50   35.360644   9160.996619
# 1              1  2020-07-05       1018.75   25.109559   9080.471295
# 2              2  2020-07-04        981.25   31.870481   9072.420000
# 3              3  2020-07-03       1018.75   53.786255   9101.928705
# 4              4  2020-07-02       1025.00   56.014037   9134.083381
# ...          ...         ...           ...         ...           ...
# 4192        4192  2009-01-13       6150.00    0.000000      0.000000
# 4193        4193  2009-01-12       4700.00    0.000000      0.000000
# 4194        4194  2009-01-11       4650.00    0.000000      0.000000
# 4195        4195  2009-01-10       3050.00    0.000000      0.000000
# 4196        4196  2009-01-09        700.00    0.000000      0.000000
#
#       Total Reward USD     hash-rate  Number of Transactions  TH/s Rewards USD
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
list(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-37514edd7fb6> in <module>
# ----> 1 list(data)
#
# NameError: name 'data' is not defined

# %%
fig, ax = plt.subplots()
ax.plot(data_rewards['TH/s Rewards USD'])

ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4197 entries, 2020-07-06 to 2009-01-09
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              4197 non-null   int64
#  1   Block Reward            4197 non-null   float64
#  2   Fee Reward              4197 non-null   float64
#  3   market-price            4197 non-null   float64
#  4   Total Reward USD        4197 non-null   float64
#  5   hash-rate               4197 non-null   float64
#  6   Number of Transactions  4197 non-null   float64
#  7   TH/s Rewards USD        4197 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 295.1 KB

# %%
data.index=pd.to_datetime(data.index)

# %%
data_1=data.resample('Y').mean()

# %%
fig, ax = plt.subplots()
ax.plot(data_1.index, data_1['TH/s Rewards USD'])

ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
plt.plot_date(data_1.index,data_1['Total Reward USD'])

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_file, show

# %%
p1 = figure(x_axis_type="datetime", title="History TH/s Value")
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Date'
p1.yaxis.axis_label = 'Price'
p1.line((data_1.index), data_1['Total Reward USD'], color='#A6CEE3', legend_label='AAPL')
p1.line((data_1.index), data_1['TH/s Rewards USD'], color='#B2DF8A', legend_label='AAPL')

show(gridplot([[p1]], plot_width=400, plot_height=400))

# %%
data_1
# Out:
#             Unnamed: 0  Block Reward    Fee Reward  market-price  \
# Timestamp
# 2009-12-31      4018.0   4550.280112  8.039216e-03      0.000000
# 2010-12-31      3657.0   9304.109589  1.205194e-01      0.062850
# 2011-12-31      3292.0   8168.082192  5.053903e+08      6.019545
# 2012-12-31      2926.5   7137.226776  1.854476e+01      8.463541
# 2013-12-31      2561.0   4344.726027  4.184801e+01    189.745239
# 2014-12-31      2196.0   4031.849315  1.270294e+01    526.413098
# 2015-12-31      1831.0   3720.616438  2.246606e+01    272.652588
# 2016-12-31      1465.5   2857.547814  6.162726e+01    565.168161
# 2017-12-31      1100.0   1915.342466  5.053905e+08   3935.668359
# 2018-12-31       735.0   1866.369863  5.053903e+08   7593.222690
# 2019-12-31       370.0   1857.260274  5.421291e+01   7366.457293
# 2020-12-31        93.5   1551.329787  4.362924e+01   8462.167775
#
#             Total Reward USD     hash-rate  Number of Transactions  \
# Timestamp
# ...

# %%
data_prueba=data_1.copy(deep=True)

# %%
def bokeh(x,y):
    p1 = figure(x_axis_type="datetime", title="History TH/s Value")
    p1.grid.grid_line_alpha=0.3
    p1.xaxis.axis_label = 'Date'
    p1.yaxis.axis_label = 'Price'
    p1.line((x.index), x[y], color='#A6CEE3', legend_label='AAPL')
    # p1.line((data_1.index), data_1['TH/s Rewards USD'], color='#B2DF8A', legend_label='AAPL')

    show(gridplot([[p1]], plot_width=400, plot_height=400))

# %%
data_prueba["TH/s Rewards USD"]=data_prueba["TH/s Rewards USD"]*1000

# %%
bokeh(data_prueba["TH/s Rewards USD"])

# %%
data_2=data_1["2017-12-31":]

# %%
bokeh(data_2,"TH/s Rewards USD")

# %% [markdown]
# # # Analicemos que sucede

# %%
data_crudo=pd.read_csv("datos_casi.csv")

# %%
data_crudo
# Out:
#       Unnamed: 0   Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0  2020-07-06        912.50   35.360644   9160.996619
# 1              1  2020-07-05       1018.75   25.109559   9080.471295
# 2              2  2020-07-04        981.25   31.870481   9072.420000
# 3              3  2020-07-03       1018.75   53.786255   9101.928705
# 4              4  2020-07-02       1025.00   56.014037   9134.083381
# ...          ...         ...           ...         ...           ...
# 4192        4192  2009-01-13       6150.00    0.000000      0.000000
# 4193        4193  2009-01-12       4700.00    0.000000      0.000000
# 4194        4194  2009-01-11       4650.00    0.000000      0.000000
# 4195        4195  2009-01-10       3050.00    0.000000      0.000000
# 4196        4196  2009-01-09        700.00    0.000000      0.000000
#
#       Total Reward USD     hash-rate
# 0         8.683348e+06  1.252805e+08
# 1         9.478737e+06  1.242343e+08
# ...

# %%
data_crudo["Timestamp"]=pd.to_datetime(data_crudo["Timestamp"])

# %%
fig, ax = plt.subplots()
ax.plot(data_crudo["Timestamp"],data_crudo['hash-rate'])

ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
data_crudo["TH/s Value USD"]=data_crudo["market-price"]/data_crudo["hash-rate"]

# %%
fig, ax = plt.subplots()
ax.plot(data_crudo_2["Timestamp"],data_crudo_2["TH/s Value USD"])

ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(data_crudo_2["Timestamp"],data_crudo_2['Th Value 2'])

ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
list(data_rewards)
# Out:
# ['Unnamed: 0',
#  'Timestamp',
#  'Block Reward',
#  'Fee Reward',
#  'market-price',
#  'Total Reward USD',
#  'hash-rate',
#  'Number of Transactions',
#  'TH/s Rewards USD']

# %%
data_rewards['Timestamp']=pd.to_datetime(data_rewards['Timestamp'])

# %%
data_rewards
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0 2020-07-06        912.50   35.360644   9160.996619
# 1              1 2020-07-05       1018.75   25.109559   9080.471295
# 2              2 2020-07-04        981.25   31.870481   9072.420000
# 3              3 2020-07-03       1018.75   53.786255   9101.928705
# 4              4 2020-07-02       1025.00   56.014037   9134.083381
# ...          ...        ...           ...         ...           ...
# 4192        4192 2009-01-13       6150.00    0.000000      0.000000
# 4193        4193 2009-01-12       4700.00    0.000000      0.000000
# 4194        4194 2009-01-11       4650.00    0.000000      0.000000
# 4195        4195 2009-01-10       3050.00    0.000000      0.000000
# 4196        4196 2009-01-09        700.00    0.000000      0.000000
#
#       Total Reward USD     hash-rate  Number of Transactions  TH/s Rewards USD
# ...

# %%
data_crudo
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0 2020-07-06        912.50   35.360644   9160.996619
# 1              1 2020-07-05       1018.75   25.109559   9080.471295
# 2              2 2020-07-04        981.25   31.870481   9072.420000
# 3              3 2020-07-03       1018.75   53.786255   9101.928705
# 4              4 2020-07-02       1025.00   56.014037   9134.083381
# ...          ...        ...           ...         ...           ...
# 4192        4192 2009-01-13       6150.00    0.000000      0.000000
# 4193        4193 2009-01-12       4700.00    0.000000      0.000000
# 4194        4194 2009-01-11       4650.00    0.000000      0.000000
# 4195        4195 2009-01-10       3050.00    0.000000      0.000000
# 4196        4196 2009-01-09        700.00    0.000000      0.000000
#
#       Total Reward USD     hash-rate  TH/s Value USD  Th Value 2
# 0         8.683348e+06  1.252805e+08        0.000073    0.069311
# ...

# %%
data_crudo["Th Value 2"]=(data_crudo["Block Reward"]+data_crudo["Fee Reward"])/data_crudo["hash-rate"]*data_crudo["market-price"]

# %%
data_crudo.loc[data_rewards["Block Reward"]==max(data_rewards["Block Reward"])]
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 3646        3646 2010-07-13       34600.0         0.0           0.0
#
#       Total Reward USD  hash-rate  TH/s Value USD  Th Value 2
# 3646               0.0   0.001138             0.0         0.0

# %%
data_crudo_2=data_crudo[data_crudo["market-price"]!=0]

# %%
data_crudo_2
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0 2020-07-06        912.50   35.360644   9160.996619
# 1              1 2020-07-05       1018.75   25.109559   9080.471295
# 2              2 2020-07-04        981.25   31.870481   9072.420000
# 3              3 2020-07-03       1018.75   53.786255   9101.928705
# 4              4 2020-07-02       1025.00   56.014037   9134.083381
# ...          ...        ...           ...         ...           ...
# 3605        3605 2010-08-23      10650.00    0.000000      0.071002
# 3606        3606 2010-08-22      10600.00    0.000000      0.070000
# 3607        3607 2010-08-21       8650.00    0.000000      0.068998
# 3608        3608 2010-08-20       9650.00    0.000000      0.068747
# 3609        3609 2010-08-19       6750.00    0.000000      0.070000
#
#       Total Reward USD     hash-rate  TH/s Value USD     Th Value 2
# 0         8.683348e+06  1.252805e+08        0.000073       0.069311
# ...

# %%
data_crudo_2.loc[data_crudo_2["Th Value 2"]==max(data_crudo_2["Th Value 2"])]

# %%
max(data_crudo_2["Fee Reward"])
# Out:
# 184467441503.1666

# %%
estudio
# Out:
#       Unnamed: 0  Timestamp  Block Reward    Fee Reward  market-price  \
# 3337        3337 2011-05-18       14400.0  1.844674e+11      7.660703
#
#       Total Reward USD  hash-rate  TH/s Value USD    Th Value 2
# 3337      1.413150e+12    2.49033         3.07618  5.674551e+11

# %%
max(old_data["Fee Reward"])
# Out:
# '94.80616665 BTC'

# %%
old_data.loc[old_data["Fee Reward"]==max(old_data["Fee Reward"])]
# Out:
#         Unnamed: 0                                               Hash  \
# 410852      410803  000000000000021853a045c480f8ca0ae78d91fc76f09f...
#
#        Confirmations           Timestamp    Height Number of Transactions  \
# 410852       409,172 2013-03-06 23:15:00  224588.0                    621
#
#           Difficulty                                        Merkle root  \
# 410852  4,367,876.00  8108b89dc5c69319b17bf4562d1f9d08a546570de94816...
#
#        Version         Bits        Weight           Size          Nonce  \
# 410852     0x2  436,459,339  2,001,536 WU  500,384 bytes  3,750,043,451
#
#         Transaction Volume     Block Reward       Fee Reward Miner Name  \
# 410852  20562.47387196 BTC  25.00000000 BTC  94.80616665 BTC    Unknown
#
#                                               URL Miner  Unnamed: 0.1
# 410852  /btc/address/159YFg4ejLgRTaB4LP65gwNKFQ74T7APf3           NaN

# %%
old_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635440 entries, 0 to 635439
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              635440 non-null  int64
#  1   Hash                    635440 non-null  object
#  2   Confirmations           635440 non-null  object
#  3   Timestamp               635440 non-null  datetime64[ns]
#  4   Height                  635440 non-null  float64
#  5   Number of Transactions  635440 non-null  object
#  6   Difficulty              635440 non-null  object
#  7   Merkle root             635440 non-null  object
#  8   Version                 635440 non-null  object
#  9   Bits                    635440 non-null  object
#  10  Weight                  635440 non-null  object
#  11  Size                    635440 non-null  object
#  12  Nonce                   635440 non-null  object
# ...

# %%
old_data=pd.read_csv("../../blockchain data/bc data/old data/data_crudo.csv")

# %%
old_data['Timestamp']=pd.to_datetime(old_data['Timestamp'])

# %% [markdown]
# # # Repitiendo todo de nuevo

# %%
list(old_data)
# Out:
# ['Unnamed: 0',
#  'Hash',
#  'Confirmations',
#  'Timestamp',
#  'Height',
#  'Number of Transactions',
#  'Difficulty',
#  'Merkle root',
#  'Version',
#  'Bits',
#  'Weight',
#  'Size',
#  'Nonce',
#  'Transaction Volume',
#  'Block Reward',
#  'Fee Reward',
#  'Miner Name',
#  'URL Miner',
#  'Unnamed: 0.1']

# %%
new_data=old_data[['Timestamp','Block Reward','Fee Reward','Number of Transactions','Height']]

# %%
new_data["Block Reward"]=new_data['Block Reward'].map(lambda x: x.rstrip(' BTC'))
new_data["Fee Reward"]=new_data['Fee Reward'].map(lambda x: x.rstrip(' BTC'))
new_data.head()
# Out:
#             Timestamp Block Reward  Fee Reward Number of Transactions  \
# 0 2020-06-19 17:09:00   6.25000000  0.42701045                  2,898
# 1 2020-06-19 16:58:00   6.25000000  0.33835014                  2,788
# 2 2020-06-19 16:50:00   6.25000000  0.33909769                  2,927
# 3 2020-06-19 16:47:00   6.25000000  0.53859435                  2,439
# 4 2020-06-19 16:29:00   6.25000000  0.41420656                  2,972
#
#      Height
# 0  635440.0
# 1  635439.0
# 2  635438.0
# 3  635437.0
# 4  635436.0

# %%
new_data["Timestamp"]=pd.to_datetime(new_data["Timestamp"])

# %%
new_data[["Block Reward",'Fee Reward']] = new_data[["Block Reward",'Fee Reward']].astype('float')

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635440 entries, 0 to 635439
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               635440 non-null  datetime64[ns]
#  1   Block Reward            635440 non-null  float64
#  2   Fee Reward              635440 non-null  float64
#  3   Number of Transactions  635440 non-null  object
#  4   Height                  635440 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 24.2+ MB

# %%
datos=new_data.groupby(pd.Grouper(key="Timestamp", freq = '1D'))[['Block Reward',"Fee Reward"]].sum()

# %%
new_data.loc[new_data["Fee Reward"]==max(new_data["Fee Reward"])]
# Out:
#          index           Timestamp  Block Reward    Fee Reward  \
# 124723  510716 2011-05-18 00:21:00          50.0  1.844674e+11
#
#        Number of Transactions    Height
# 124723                      8  124724.0

# %%
new_data[new_data["Fee Reward"]==184467440724.5955]
# Out:
#          index           Timestamp  Block Reward    Fee Reward  \
# 501725  133714 2017-12-30 12:55:00          12.5  1.844674e+11
#
#        Number of Transactions    Height
# 501725                      1  501726.0

# %%
new_data=new_data.sort_values(by=['Height'],ascending=True)

# %%
new_data["Fee Reward"][124723]
# Out:
# 184467440737.09552

# %%
new_data["Fee Reward"][124723]

# %%
new_data.loc[new_data["Height"]==124724]
# Out:
#          index           Timestamp  Block Reward    Fee Reward  \
# 124723  510716 2011-05-18 00:21:00          50.0  1.844674e+11
#
#        Number of Transactions    Height
# 124723                      8  124724.0

# %%
data_rewards
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 0              0 2020-07-06        912.50   35.360644   9160.996619
# 1              1 2020-07-05       1018.75   25.109559   9080.471295
# 2              2 2020-07-04        981.25   31.870481   9072.420000
# 3              3 2020-07-03       1018.75   53.786255   9101.928705
# 4              4 2020-07-02       1025.00   56.014037   9134.083381
# ...          ...        ...           ...         ...           ...
# 4192        4192 2009-01-13       6150.00    0.000000      0.000000
# 4193        4193 2009-01-12       4700.00    0.000000      0.000000
# 4194        4194 2009-01-11       4650.00    0.000000      0.000000
# 4195        4195 2009-01-10       3050.00    0.000000      0.000000
# 4196        4196 2009-01-09        700.00    0.000000      0.000000
#
#       Total Reward USD     hash-rate  Number of Transactions  TH/s Rewards USD
# ...

# %%
new_data
# Out:
#                  Timestamp  Block Reward  Fee Reward Number of Transactions  \
# 0      2020-06-19 17:09:00          6.25    0.427010                  2,898
# 1      2020-06-19 16:58:00          6.25    0.338350                  2,788
# 2      2020-06-19 16:50:00          6.25    0.339098                  2,927
# 3      2020-06-19 16:47:00          6.25    0.538594                  2,439
# 4      2020-06-19 16:29:00          6.25    0.414207                  2,972
# ...                    ...           ...         ...                    ...
# 635435 2009-01-09 03:23:00         50.00    0.000000                      1
# 635436 2009-01-09 03:16:00         50.00    0.000000                      1
# 635437 2009-01-09 03:02:00         50.00    0.000000                      1
# 635438 2009-01-09 02:55:00         50.00    0.000000                      1
# 635439 2009-01-09 02:54:00         50.00    0.000000                      1
#
#           Height
# 0       635440.0
# 1       635439.0
# ...

# %%
max(new_data["Fee Reward"])
# Out:
# 291.53275103

# %%
datos=new_data.groupby(pd.Grouper(key="Timestamp", freq = '1D'))[['Block Reward',"Fee Reward"]].sum()

# %%
datos
# Out:
#             Block Reward  Fee Reward
# Timestamp
# 2009-01-09        700.00    0.000000
# 2009-01-10       3050.00    0.000000
# 2009-01-11       4650.00    0.000000
# 2009-01-12       4700.00    0.000000
# 2009-01-13       6150.00    0.000000
# ...                  ...         ...
# 2020-06-15        862.50   34.183159
# 2020-06-16        937.50   50.597425
# 2020-06-17        862.50   47.792641
# 2020-06-18        768.75   44.082697
# 2020-06-19        631.25   38.236424
#
# [4180 rows x 2 columns]

# %%
max(datos["Fee Reward"])
# Out:
# 184467441503.1666

# %% [markdown]
# ---- Limpiando un poco el area de trabajo

# %%
new_data.loc[new_data["Fee Reward"]==max(new_data["Fee Reward"])]
# Out:
#            index           Timestamp  Block Reward  Fee Reward  \
# Height
# 409008.0  226432 2016-04-26 14:15:00          25.0  291.532751
#
#          Number of Transactions    Height
# Height
# 409008.0                  1,962  409008.0

# %%
new_data.loc[new_data["Fee Reward"]==max(new_data["Fee Reward"])]
# Out:
#            index           Timestamp  Block Reward  Fee Reward  \
# Height
# 409008.0  226432 2016-04-26 14:15:00          25.0  291.532751
#
#          Number of Transactions    Height
# Height
# 409008.0                  1,962  409008.0

# %%
new_data["Fee Reward"][501726]
# Out:
# 184467440724.5955

# %%
new_data["Fee Reward"][501726]=0.0

# %%
data_rewards.loc[data_rewards["Timestamp"]==pd.to_datetime("2016-04-26")]
# Out:
#       Unnamed: 0  Timestamp  Block Reward  Fee Reward  market-price  \
# 1532        1532 2016-04-26        3775.0  337.755574    459.749482
#
#       Total Reward USD     hash-rate  Number of Transactions  TH/s Rewards USD
# 1532      1.890837e+06  1.361879e+06                250744.0          1.388403

# %%
new_data.to_csv("datos_casi.csv")

# %%
new_data
# Out:
#                  Timestamp  Block Reward  Fee Reward Number of Transactions
# 0      2009-01-09 02:54:00         50.00    0.000000                      1
# 1      2009-01-09 02:55:00         50.00    0.000000                      1
# 2      2009-01-09 03:02:00         50.00    0.000000                      1
# 3      2009-01-09 03:16:00         50.00    0.000000                      1
# 4      2009-01-09 03:23:00         50.00    0.000000                      1
# ...                    ...           ...         ...                    ...
# 635435 2020-06-19 16:29:00          6.25    0.414207                  2,972
# 635436 2020-06-19 16:47:00          6.25    0.538594                  2,439
# 635437 2020-06-19 16:50:00          6.25    0.339098                  2,927
# 635438 2020-06-19 16:58:00          6.25    0.338350                  2,788
# 635439 2020-06-19 17:09:00          6.25    0.427010                  2,898
#
# [635440 rows x 4 columns]

# %%
new_data=new_data[["Timestamp","Block Reward","Fee Reward","Number of Transactions"]]

# %%
new_data=new_data.reset_index()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635440 entries, 0 to 635439
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Height                  635440 non-null  float64
#  1   Timestamp               635440 non-null  datetime64[ns]
#  2   Block Reward            635440 non-null  float64
#  3   Fee Reward              635440 non-null  float64
#  4   Number of Transactions  635440 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 24.2+ MB

# %%
new_data["Number of Transactions"].replace(",","")
# Out:
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#           ...
# 635435    2,972
# 635436    2,439
# 635437    2,927
# 635438    2,788
# 635439    2,898
# Name: Number of Transactions, Length: 635440, dtype: object

# %%
new_data=new_data.drop(columns="Height",axis=1)

# %%
data_prueba=new_data.copy(deep=True)

# %%
data_prueba.replace({"Number of Transactions":r","},{"Number of Transactions":""})
# Out:
#                  Timestamp  Block Reward  Fee Reward Number of Transactions
# 0      2009-01-09 02:54:00         50.00    0.000000                      1
# 1      2009-01-09 02:55:00         50.00    0.000000                      1
# 2      2009-01-09 03:02:00         50.00    0.000000                      1
# 3      2009-01-09 03:16:00         50.00    0.000000                      1
# 4      2009-01-09 03:23:00         50.00    0.000000                      1
# ...                    ...           ...         ...                    ...
# 635435 2020-06-19 16:29:00          6.25    0.414207                  2,972
# 635436 2020-06-19 16:47:00          6.25    0.538594                  2,439
# 635437 2020-06-19 16:50:00          6.25    0.339098                  2,927
# 635438 2020-06-19 16:58:00          6.25    0.338350                  2,788
# 635439 2020-06-19 17:09:00          6.25    0.427010                  2,898
#
# [635440 rows x 4 columns]

# %%
data_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635440 entries, 0 to 635439
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Timestamp               635440 non-null  datetime64[ns]
#  1   Block Reward            635440 non-null  float64
#  2   Fee Reward              635440 non-null  float64
#  3   Number of Transactions  635440 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 19.4+ MB
