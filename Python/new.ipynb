# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data_reward_casi.csv")

# %%
data
# Out:
#        Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0     2020-06-19        631.25   38.236424                247066.0
# 1     2020-06-18        768.75   44.082697                280603.0
# 2     2020-06-17        862.50   47.792641                333547.0
# 3     2020-06-16        937.50   50.597425                340517.0
# 4     2020-06-15        862.50   34.183159                294468.0
# ...          ...           ...         ...                     ...
# 3588  2010-08-23      10650.00    0.000000                   369.0
# 3589  2010-08-22      10600.00    0.000000                   366.0
# 3590  2010-08-21       8650.00    0.000000                   342.0
# 3591  2010-08-20       9650.00    0.000000                   423.0
# 3592  2010-08-19       6750.00    0.000000                   325.0
#
#       market-price     hash-rate
# 0          9380.03  1.114223e+08
# 1          9410.94  1.097398e+08
# 2          9427.12  1.080573e+08
# ...

# %%
data["Timestamp"]=pd.to_datetime(data["Timestamp"])

# %%
data["TH/USD Value"]=((data["Block Reward"]+data["Fee Reward"])/data["hash-rate"])*data["market-price"]

# %%
data["Total Miners Rewards USD"]=(data["Block Reward"]+data["Fee Reward"])*data["market-price"]

# %%
fig, ax = plt.subplots()
p1=ax.plot(data["Timestamp"],data["Number of Transactions"])
# p2=ax.plot(data["Timestamp"],data["TH/USD Value"])
p3=ax.plot(data["Timestamp"],data["market-price"])
# p4=ax.plot(data["Timestamp"],data["Total Miners Rewards USD"])
fig.set_size_inches(18.5, 10.5)
ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()
# Out:
# (None, None)

# %%
data
# Out:
#       Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0    2020-06-19        631.25   38.236424                247066.0
# 1    2020-06-18        768.75   44.082697                280603.0
# 2    2020-06-17        862.50   47.792641                333547.0
# 3    2020-06-16        937.50   50.597425                340517.0
# 4    2020-06-15        862.50   34.183159                294468.0
# ...         ...           ...         ...                     ...
# 3588 2010-08-23      10650.00    0.000000                   369.0
# 3589 2010-08-22      10600.00    0.000000                   366.0
# 3590 2010-08-21       8650.00    0.000000                   342.0
# 3591 2010-08-20       9650.00    0.000000                   423.0
# 3592 2010-08-19       6750.00    0.000000                   325.0
#
#       market-price     hash-rate   TH/USD Value  Total Miners Rewards USD
# 0          9380.03  1.114223e+08       0.056360              6.279803e+06
# ...

# %%
data.describe()
# Out:
#        Block Reward   Fee Reward  Number of Transactions  market-price  \
# count   3593.000000  3593.000000             3593.000000   3593.000000
# mean    4079.183482    59.551544           150417.440301   2478.409090
# std     2552.381372   106.968155           120407.454850   3635.798912
# min      631.250000     0.000000              260.000000      0.050000
# 25%     1925.000000    13.385099            42580.000000     22.870000
# 50%     3650.000000    25.685026           119343.000000    449.130000
# 75%     4925.000000    52.002641           256015.000000   4104.710000
# max    15350.000000  1495.946477           490644.000000  19279.900000
#
#           hash-rate   TH/USD Value  Total Miners Rewards USD
# count  3.593000e+03    3593.000000              3.593000e+03
# mean   1.647587e+07    4537.751430              5.139006e+06
# std    3.066157e+07   15163.254223              7.491102e+06
# min    4.248547e-03       0.056360              3.000005e+02
# ...

# %% [markdown]
# # Queremos saber si hay corroborancia con TH/USD respecto a los demas

# %%
data["sum Reward"]=data["Block Reward"]+data["Fee Reward"]

# %%
data
# Out:
#       Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0    2020-06-19        631.25   38.236424                247066.0
# 1    2020-06-18        768.75   44.082697                280603.0
# 2    2020-06-17        862.50   47.792641                333547.0
# 3    2020-06-16        937.50   50.597425                340517.0
# 4    2020-06-15        862.50   34.183159                294468.0
# ...         ...           ...         ...                     ...
# 3588 2010-08-23      10650.00    0.000000                   369.0
# 3589 2010-08-22      10600.00    0.000000                   366.0
# 3590 2010-08-21       8650.00    0.000000                   342.0
# 3591 2010-08-20       9650.00    0.000000                   423.0
# 3592 2010-08-19       6750.00    0.000000                   325.0
#
#       market-price     hash-rate   TH/USD Value  Total Miners Rewards USD  \
# 0          9380.03  1.114223e+08       0.056360              6.279803e+06
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True,linewidths=.5)

# %% [markdown]
# # Concluimos que:
# ## BLock Reward:
#    - Hay correlacion negativa con el numero de transacciones.
#      La explicacion a esto es respecto al tiempo ya que a medida que el
#      block reward disminuye en el tiempo y el numero de transacciones aumenta.
#     Satoshi dijo una vez: ***en algunos años veremos una gran cantidad de transaciones
#     de bitcoin o no***. Aunque woww su prediccion simplemente se basa en funcionara o no. 50 y 50
#     y Funciona!.
#
#     - Correlacion negativa entre el block reward y el market price.
#       a medida que el block reward disminuye tiende aumentar el precio
#       del BTC, es logico debido a la desflacion pero (-0.57) pensaba un
#       numero mas cercano al -1
# _________________________________________________
#
# ## Fee reward:
# - A medida que block reward disminuye en el tiempo.
#     El fee reward aumenta!
#     Intentando compensar la escacez que genera el Block Reward.En un futuro de 10 años,
#     la mineria dependera totalmente de el Fee Reward
# - Correlacion baja entre el numero de transaccion y el fee reward, me esperaba
#     una correlacion mas notoria ya que a mayor cantidad de transacciones
#     mayor recaudacion del Fee Reward
# _________________________________________________
#
# ## Number of Transaction:
# - Correlacion entre el precio y market price!
#     Un buen indicador!
#     Si eres Trader, deberias tomar en cuenta el numero de Transacciones para entender la tendencia del mercado
# _________________________________________________
#
# ## TH/USD Value:
# - Correlacion baja con el block reward
# - No hay correlacion entre fe reward
# -no hay correlacion alguna entre el precio del BTC y el valor del TH
#    En conclucion el valor del TH muestra solo dependencia del Block Reward y no es muy notorio. Aunque concluimos que
#    al paso del tiempo el valor TH se ira depreciando, es decir debemos aumentar nuestro computo cada vez mas y mas.
# _________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_scale=scaler.fit(data[["TH/USD Value",'market-price']])

# %%
data_scale
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.transform(data[['market-price','TH/USD Value']])
# Out:
# array([[4.56809461e-02, 3.29898302e-07],
#        [4.58314793e-02, 1.02210253e-06],
#        [4.59102767e-02, 1.52571855e-06],
#        ...,
#        [6.64255916e-08, 6.16216261e+00],
#        [6.64255916e-08, 7.49837691e+00],
#        [6.64255916e-08, 5.76842903e+00]])

# %%
list(data)
# Out:
# ['Timestamp',
#  'Block Reward',
#  'Fee Reward',
#  'Number of Transactions',
#  'market-price',
#  'hash-rate',
#  'TH/USD Value',
#  'Total Miners Rewards USD',
#  'sum Reward']

# %%
data
# Out:
#       Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0    2020-06-19        631.25   38.236424                247066.0
# 1    2020-06-18        768.75   44.082697                280603.0
# 2    2020-06-17        862.50   47.792641                333547.0
# 3    2020-06-16        937.50   50.597425                340517.0
# 4    2020-06-15        862.50   34.183159                294468.0
# ...         ...           ...         ...                     ...
# 3588 2010-08-23      10650.00    0.000000                   369.0
# 3589 2010-08-22      10600.00    0.000000                   366.0
# 3590 2010-08-21       8650.00    0.000000                   342.0
# 3591 2010-08-20       9650.00    0.000000                   423.0
# 3592 2010-08-19       6750.00    0.000000                   325.0
#
#       market-price     hash-rate   TH/USD Value  Total Miners Rewards USD  \
# 0          9380.03  1.114223e+08       0.056360              6.279803e+06
# ...

# %%
data
# Out:
#       Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0    2020-06-19        631.25   38.236424                247066.0
# 1    2020-06-18        768.75   44.082697                280603.0
# 2    2020-06-17        862.50   47.792641                333547.0
# 3    2020-06-16        937.50   50.597425                340517.0
# 4    2020-06-15        862.50   34.183159                294468.0
# ...         ...           ...         ...                     ...
# 3588 2010-08-23      10650.00    0.000000                   369.0
# 3589 2010-08-22      10600.00    0.000000                   366.0
# 3590 2010-08-21       8650.00    0.000000                   342.0
# 3591 2010-08-20       9650.00    0.000000                   423.0
# 3592 2010-08-19       6750.00    0.000000                   325.0
#
#       market-price     hash-rate   TH/USD Value  Total Miners Rewards USD  \
# 0          9380.03  1.114223e+08       0.056360              6.279803e+06
# ...

# %% [markdown]
# # Rentabilidad del s9

# %%
data.to_csv("history_data_rewards.csv")

# %%
data.set_index(data["Timestamp"])
# Out:
#             Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# Timestamp
# 2020-06-19 2020-06-19        631.25   38.236424                247066.0
# 2020-06-18 2020-06-18        768.75   44.082697                280603.0
# 2020-06-17 2020-06-17        862.50   47.792641                333547.0
# 2020-06-16 2020-06-16        937.50   50.597425                340517.0
# 2020-06-15 2020-06-15        862.50   34.183159                294468.0
# ...               ...           ...         ...                     ...
# 2010-08-23 2010-08-23      10650.00    0.000000                   369.0
# 2010-08-22 2010-08-22      10600.00    0.000000                   366.0
# 2010-08-21 2010-08-21       8650.00    0.000000                   342.0
# 2010-08-20 2010-08-20       9650.00    0.000000                   423.0
# 2010-08-19 2010-08-19       6750.00    0.000000                   325.0
#
#             market-price     hash-rate   TH/USD Value  \
# Timestamp
# ...

# %%
data_2016=data[data["Timestamp"]>pd.to_datetime("2016-01-01")]

# %%
data_2016
# Out:
#       Timestamp  Block Reward  Fee Reward  Number of Transactions  \
# 0    2020-06-19        631.25   38.236424                247066.0
# 1    2020-06-18        768.75   44.082697                280603.0
# 2    2020-06-17        862.50   47.792641                333547.0
# 3    2020-06-16        937.50   50.597425                340517.0
# 4    2020-06-15        862.50   34.183159                294468.0
# ...         ...           ...         ...                     ...
# 1626 2016-01-06       3525.00   30.403244                172090.0
# 1627 2016-01-05       3925.00   32.278467                182371.0
# 1628 2016-01-04       4525.00   30.746843                181354.0
# 1629 2016-01-03       3625.00   24.083049                142608.0
# 1630 2016-01-02       3625.00   31.376005                149038.0
#
#       market-price     hash-rate  TH/USD Value  Total Miners Rewards USD  \
# 0          9380.03  1.114223e+08      0.056360              6.279803e+06
# ...

# %%
data_s19=data_2016[['Timestamp',"market-price",'TH/USD Value']]

# %%
data_s9["Profit USD"]=data_s9["market-price"]*data_s9["TH/USD Value"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-158c6e348867> in <module>
# ----> 1 data_s19["Profit USD"]=data_s19["TH/USD Value"]*110
#
# NameError: name 'data_s19' is not defined

# %%
data_s9=data_s9.groupby(pd.Grouper(key="Timestamp", freq = '1M'))[["Profit USD"]].sum()

# %%
fig, ax = plt.subplots()
ax.plot(data_s9.index,data_s9["Profit USD"])
# ax.plot(data_s19.index,data_s19["Profit USD"])
fig.set_size_inches(18.5, 10.5)
ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
data_2020=data[data["Timestamp"]>pd.to_datetime("2020-03-24")]

# %%
data_s19=data_2020[['Timestamp',"market-price",'TH/USD Value']]

# %%
data_s19["Profit USD"]=data_s19["TH/USD Value"]*110

# %%
data_s19=data_s19.groupby(pd.Grouper(key="Timestamp", freq = '1M'))[["Profit USD"]].sum()

# %%
data_s19
# Out:
#             Profit USD
# Timestamp
# 2020-03-31   84.893635
# 2020-04-30  401.487883
# 2020-05-31  385.616088
# 2020-06-30  184.892577

# %%
fig, ax = plt.subplots()
ax.plot(data_s9.index,data_s9["Profit USD"])
ax.plot(data_s19.index,data_s19["Profit USD"])
ax.plot(data_s7.index,data_s7["Profit USD"])
fig.set_size_inches(18.5, 10.5)
ax.set(xlabel='Total Reward USD', ylabel='USD',
       title='History TH/s Value ')
ax.grid()
plt.show()

# %%
data_2015=data[data["Timestamp"]>pd.to_datetime("2015-09-01")]

# %%
data_s7=data_2015[['Timestamp',"market-price",'TH/USD Value']]

# %%
data_s7["Profit USD"]=data_s7["TH/USD Value"]*4.73

# %%
data_s7=data_s7.groupby(pd.Grouper(key="Timestamp", freq = '1M'))[["Profit USD"]].sum()
